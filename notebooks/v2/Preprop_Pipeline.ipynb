# %% [markdown]
# # Imports and Makros

# %%
import sys
sys.path.append('../..')

from src.data_loader import DataLoader
from src.pickle_loader import PickleLoader

from src.utils.byte_pair_encoding import BytePairEncoder
from src.preprocessing.dictionary import Dictionary
from src.preprocessing.batching import Batcher

from multiprocessing import Pool

# %%
BATCH_SIZE = 200
WINDOW_SIZE = 4
BPE_OPERATIONS = 5000

# %% [markdown]
# # Load data

# %%
target_data_loader = DataLoader('../../data/data_v2/multi30k.en.gz')
source_data_loader = DataLoader('../../data/data_v2/multi30k.de.gz')

target_data_raw = target_data_loader.load_data()
source_data_raw = source_data_loader.load_data()

target_data_lines = target_data_loader.tokenize(mode="lines")
source_data_lines = source_data_loader.tokenize(mode="lines")

# %% [markdown]
# # Byte-Pair-Encoding

# %%
# fit target encoder
target_encoder = BytePairEncoder()
target_encoder.fit(target_data_loader.load_data(), BPE_OPERATIONS)
# Out:
# Processing Text: 100%|██████████| 5000/5000 [00:24<00:00, 206.14it/s, New Token=advice, New Rule=ad vice -> advice]

# %%
# fit source encoder
source_encoder = BytePairEncoder()
source_encoder.fit(source_data_loader.load_data(), BPE_OPERATIONS)
# Out:
# Processing Text: 100%|██████████| 5000/5000 [00:59<00:00, 84.50it/s, New Token=wickeln, New Rule=wickel n -> wickeln]

# %%
# encode target data
target_data_encoded = target_encoder.encode_corpus(target_data_lines, multi_process=True)

# %%
# encode source data
source_data_encoded = source_encoder.encode_corpus(source_data_lines, multi_process=True)

# %%
# Out:
# [['<s>', 'zwei', 'junge', 'weiße', 'männer', 'sind', 'im', 'freien', 'in', 'der', 'nähe', 'vieler', 'büsche', '.', '</s>'], ['<s>', 'mehrere', 'männer', 'mit', 'schutzhelmen', 'bedienen', 'ein', 'antrie@@', 'b@@', 's@@', 'radsystem', '.', '</s>'], ['<s>', 'ein', 'kleines', 'mädchen', 'klettert', 'in', 'ein', 'spielhaus', 'aus', 'holz', '.', '</s>'], ['<s>', 'ein', 'mann', 'in', 'einem', 'blauen', 'hemd', 'steht', 'auf', 'einer', 'leiter', 'und', 'putzt', 'ein', 'fenster', '.', '</s>'], ['<s>', 'zwei', 'männer', 'stehen', 'am', 'herd', 'und', 'bereiten', 'essen', 'zu', '.', '</s>'], ['<s>', 'ein', 'mann', 'in', 'grün', 'hält', 'eine', 'gitarre', ',', 'während', 'der', 'andere', 'mann', 'sein', 'hemd', 'ansieht', '.', '</s>'], ['<s>', 'ein', 'mann', 'lächelt', 'einen', 'ausgestopften', 'löwen', 'an', '.', '</s>'], ['<s>', 'ein', 'schickes', 'mädchen', 'spricht', 'mit', 'dem', 'handy', 'während', 'sie', 'langsam', 'die', 'straße', 'entlangschwebt', '.', '</s>'], ['<s>', 'eine', 'frau', 'mit', 'einer', 'großen', 'geldbörse', 'geht', 'an', 'einem', 'tor', 'vorbei', '.', '</s>'], ['<s>', 'jungen', 'tanzen', 'mitten', 'in', 'der', 'nacht', 'auf', 'pfosten', '.', '</s>'], ['<s>', 'eine', 'ballettklasse', 'mit', 'fünf', 'mädchen', ',', 'die', 'nacheinander', 'springen', '.', '</s>'], ['<s>', 'vier', 'typen', ',', 'von', 'denen', 'drei', 'hüte', 'tragen', 'und', 'einer', 'nicht', ',', 'springen', 'oben', 'in', 'einem', 'treppenhaus', '.', '</s>'], ['<s>', 'ein', 'schwarzer', 'hund', 'und', 'ein', 'gefleckter', 'hund', 'kämpfen', '.', '</s>'], ['<s>', 'ein', 'mann', 'in', 'einer', 'neongrünen', 'und', 'orangefarbenen', 'uniform', 'fährt', 'auf', 'einem', 'grünen', 'traktor', '.', '</s>'], ['<s>', 'mehrere', 'frauen', 'warten', 'in', 'einer', 'stadt', 'im', 'freien', '.', '</s>'], ['<s>', 'eine', 'frau', 'mit', 'schwarzem', 'oberteil', 'und', 'brille', 'streut', 'puderzucker', 'auf', 'einem', 'gugel@@', 'hupf', '.', '</s>'], ['<s>', 'ein', 'kleines', 'mädchen', 'sitzt', 'vor', 'einem', 'großen', 'gemalten', 'regenbogen', '.', '</s>'], ['<s>', 'ein', 'mann', 'liegt', 'auf', 'der', 'bank', ',', 'an', 'die', 'auch', 'ein', 'weißer', 'hund', 'angebunden', 'ist', '.', '</s>'], ['<s>', 'fünf', 'personen', 'sitzen', 'mit', 'instrumenten', 'im', 'kreis', '.', '</s>'], ['<s>', 'eine', 'gruppe', 'älterer', 'frauen', 'spielt', 'zusammen', 'klarinette', 'von', 'notenblättern', '.', '</s>'], ['<s>', 'ein', 'großes', 'bauwerk', 'ist', 'kaput@@', 't', 'gegangen', 'und', 'liegt', 'auf', 'einer', 'fahrbahn', '.', '</s>'], ['<s>', 'eine', 'große', 'menschenmenge', 'steht', 'außen', 'vor', 'dem', 'eingang', 'einer', 'metrostation', '.', '</s>'], ['<s>', 'ein', 'mann', ',', 'der', 'ein', 'tattoo', 'auf', 'seinem', 'rücken', 'erhält', '.', '</s>'], ['<s>', 'zwei', 'kinder', 'sitzen', 'auf', 'einer', 'kleinen', 'wippe', 'im', 'sand', '.', '</s>'], ['<s>', 'ein', 'mann', ',', 'der', 'eine', 'reflektierende', 'weste', 'und', 'einen', 'schutzhelm', 'trägt', ',', 'hält', 'eine', 'flagge', 'in', 'die', 'straße', '.', '</s>'], ['<s>', 'eine', 'person', 'in', 'einem', 'blauen', 'mantel', 'steht', 'auf', 'einem', 'belebten', 'gehweg', 'und', 'betrachtet', 'ein', 'gemälde', 'einer', 'straßenszene', '.', '</s>'], ['<s>', 'ein', 'mann', 'in', 'grünen', 'hosen', 'läuft', 'die', 'straße', 'entlang', '.', '</s>'], ['<s>', 'das', 'kleine', 'kind', 'klettert', 'an', 'roten', 'seilen', 'auf', 'einem', 'spielplatz', '.', '</s>'], ['<s>', 'du', 'weißt', ',', 'dass', 'ich', 'aussehe', 'wie', 'justin', 'bie@@', 'ber', '.', '</s>'], ['<s>', 'ein', 'junger', 'mann', 'in', 'einer', 'schwarz-gelben', 'jacke', 'blickt', 'etwas', 'an', 'und', 'lächelt', '.', '</s>'], ['<s>', 'ein', 'mann', ',', 'der', 'mit', 'einer', 'tasse', 'kaffee', 'an', 'einem', 'urinal', 'steht', '.', '</s>'], ['<s>', 'fünf', 'gehende', 'personen', 'mit', 'einem', 'mehrfarbigen', 'himmel', 'im', 'hintergrund', '.', '</s>'], ['<s>', 'ein', 'alter', 'mann', ',', 'der', 'allein', 'ein', 'bier', 'trinkt', '.', '</s>'] ...

# %% [markdown]
# # Dictionary

# %%
# create target dictionary
target_dictionary = Dictionary(save_model=False)
target_dictionary.update(target_data_encoded)
# Out:
# {'<UNK>': -1, '<s>': 0, '</s>': 1}
# dict_keys(['<UNK>', '<s>', '</s>', 'pebble', 'hiker', 'on@@', 'reviewing', 'chest', 'tug', 'atmosphere', 'chevrolet', 'indoor', 'oration', 'appetizer', 'downs', 'secured', 'inkwell', 'stomach@@', 'middle-age', '1950s', 'hurting', 'designer', 'mailman', 'kne@@', 'cyclist', 'outcropping', 'oddly', 'inspecting', 'panasonic', 'sportswoman', 'funny', 'adventurous', 'circular', 'skateboard', 'commute', 'wheelchairs', 'supervised', 'sticking', 'penske', 'mountaineers', 'mustang', 'expectan@@', 'ft', 'suspenders', 'freezer', 'mussel', 'brushed', 'footballers', 'windowless', 'vocal', 'wields', 'lounges', 'pout', 'nescafe', 'speeds', 'lot', 'much', 'wrap', 'foli@@', 'girlfriends', '-style', 'alaska', 'land', 'obstructing', 'kar@@', 'zebra', 'driveway', 'staring', 'italy', 'cream', 'boys', 'pass', 'bowling', 'vegetable', 'mittens', 'literature', 'o@@', 'outfielders', 'videotapes', 'liner', 'spiked', 'tagged', 'del@@', 'geishas', 'attrative', 'smel@@', 'photographers', 'donkey', 'pictures', 'kite', 'touches', 'machines', 'shuffles', 'plowing', 'push@@', 'crowd@@', 'comb', 'socks', '9', 'u', 'white-striped', 'daisies', 'carton', 'intertwined', 'source', 'shingle', 'bathe', 'gators', 'risk', 'ladders', 'class', 'martial', 'belts', 'negoti@@', 'bins', 'go-cart', 'calendar', 'countryside', 'jet', 'domen', 'stares', 'morowski', 'walk', 'dojo', 'metropolitan', 'fantasy', 'oversees', 'digital', 'passage', 'dramatic', 'wipes', 'swallowing', 'kimono', 'turkish', 'musket', 'portly', 'mini', 'escalator', 'sends', 'beach@@', 'feeds', 'humans', 'cathedral', 'for@@', 'aggressively', 'belong', 'examining', 'circuits', 'morgan', 'wearfing', 'tow-truck', 'passes', 'violation', 'cupping', 'almost', 'flashes', 'seaworld', 'decorated', 'skit', 'longing', 'zippered', 'surronded', 'plen@@', 'tracksuits', 'bounding', 'introduces', 'wuth', 'preteen', 'casual', 'attacked', 'beats', 'ovals', 'playpen', 'chase', 'regrets', 'taupe', 'med-evil', 'citizens', 'balance', 'rescue', 'matador', 'rods', 'paintball', 'cupboard', 'zombies', 'axes', 'shacking', 'mud@@', 'kill', 'histories', 'fearing', 'challenge', 'loom@@', 'parachutist', 'sorted', 'overcoat', 'corners', 'noise', 'grand@@', 'rounds', 'prom', 'iran', 'charging', 'arid', 'scooby', 'fluid', 'camels', 'longhaired', 'box', 'sit', 'platform', 'silverware', 'mustache', 'somersault', 'fishnets', 'mini-@@', 'above', 'loop', 'hut', 'challenging', 'trikes', 'clustered', 'bombard', 'sauce', 'pours', 'seating', 'steer', 'cer', 'ancient', 'musician', 'buttocks', 'or', 'brad@@', 'petty', 'forest', 'minnesota', 'sing', 'napkins', 'weating', 'grownups', 'instructs', 'library', 'shews', 'trophy', 'toad', 'bernard', 'midair', 'swaddled', 'opens', 'spice', 'campsite', 'coughing', 'carrying', 'dials', 'facial', 'shadowed', 'save', 'grace@@', 'jog', 'sleepy', 'showroom', 'tablet', 'mainly', 'draped', 'after', 'l', 'teddy', 'coupe', 'self', 'bat', 'launches', 'intently', 'husky-like', 'parasail', 'waterskiing', 'cheerfully', 'loud', 'excitement', 'practice', 'portland', 'bians', 'stands', 'huddled', 'n', 'boots', 'sunrise', 'pueblo', 'miami', 'columnar', 'mops', 'pirates', 'brindle-colored', 'tracker', 'cathedral@@', 'skiiers', 'rapids', 'bunches', 'tomatos', 'rusting', 'linens', 'barber', 'outboard', 'bobsled', 'lawn', 'gras', 'maruga', 'observe', 'bicycle', 'ar', 'protesters', 'adamantly', 'scrubbing', 'poorly', 'refreshing', 'thatched', 'cleaver', 'kidding', 'entrance', 'ask', 'pee', 'waiter', 'playful', 'cosmetics', 'sunflower', 'leather', 'cutter', 'cafe', 'restaurant@@', 'mc@@', 'type', 'euro', 'ow', 'bead', 'slanting', 'smirking', 'nail', 'presence', 'decent', 'violence', 'naval', 'isra@@', 'doors', 'pay@@', 'crack', 'virou', 'attendant', 'feature', 'beech', 'wonderment', 'notice', 'ninja', 'kuthhoop', 'beans', 'brick-and-glass', 'chair@@', 'taught', 'wraps', 'fours', 'soup', 'colourful', 'reddish', 'supervise', 'consume', 've', 'gardener', 'holders', 'hood', 'solid', 'ridding', 'laundry', 'kilburn', 'hovering', 'near', 'unev ...

# %%
# create source_dictionary
source_dictionary = Dictionary(save_model=False)
source_dictionary.update(source_data_encoded)
# Out:
# {'<UNK>': -1, '<s>': 0, '</s>': 1}
# dict_keys(['<UNK>', '<s>', '</s>', 'lederweste', 'karikatur@@', 'lauschen', 'on@@', 'ordnet', 'herumgehende', 'mahl', 'fakt', 'flossen', 'früchtestand', 'bination', 'nung', 'chevrolet', 'var@@', 'pilze', 'gelen@@', 'anblick', 'verkaufsautomaten', 'kleid', 'fahrradreifen', 'kopfüber', 'drähten', 'hmem', 'legosteinen', 'catering-@@', 'messern', 'walter@@', 'marineblaue', 'kopfsteinen', 'dribbelt', 'rudern@@', 'skalen@@', 'sicherheitsausrüstung', 'suche', 'nägel', 'designer', 'ruht', 'protestiert', 'bon@@', 'auslagenfenster', 'abgewandte', 'afroamerikanerin', 'fläche', 'strandes', 'abends', 'anzügen', 'anstrich', 'zweig', 'menschen', 'redaktion', 'leb@@', 'kannt', 'steindenkmal', 'grünanlagen', 'sarbeiter', 'skateboard', 'abgestimmten', 'händler', 'spitzen', 'dekorierte', 'förmlicher', 'langär@@', 'footballticket', 'mungs@@', 'wasch@@', 'radsportler', 'soldaten', 'spielsteuerung', 'business-kleidung', 'gemachte', 'paddel', 'kulti@@', 'ablauf@@', 'schmutzigen', 'burg', 'niedrige', 'kehr@@', 'fänger', 'abgefülltem', 'gefüllten', 'genaue', 'ft', 'jeansrock', 'kirsche', 'bauern', 'federstirnbändern', 'blaugrünes', 'hepaar', 'langt', 'flippigen', 'metallarbeiter', 'reflektierenden', 'badewanne', 'a-schild', 'bergsicht', 'hohem', 'zuckerstange', 'hawaii-hemd', 'bierdosen', 'besuchern', 'motorisierten', 'gebrauchte', 'herumgedreht', 'vete', 'hol@@', 'kunststoff', 'essend', 'gelernt', 'reißverschluss', 'gipfel@@', 'dreirads', 'fahrtschild', 'flinke', 'altmodischer', 'welchen', 'zur', 'weine', 'bereit@@', 'laufbands', 'zementweg', 'tiefschnee', 'land', 'alaska', 'kar@@', 'einlaufenden', 'heraus@@', 'vorbeizu@@', 'schwal@@', 'mobil@@', 'strandpromenade', 'auch', 'betonrampe', 'förderband', 'cream', 'erd-', 'diagramme', 'pass', 'boys', 'maskottchen', 'hartholzfußboden', 'bowling', 'vorbei@@', 'o@@', 'hellem', 'bereitschaftspolizisten', 'front@@', 'freistil', 'liner', 'nadelstreifenanzug', 'kata@@', 'listischen', 'gefäß', 'zugewandten', 'spanischer', 'derobe', 'liegender', 'hawaiishorts', 'kontrollanzeige', 'schlauchleitung', 'gruppenaktivität', 'fen', 'del@@', 'geishas', 'radschlag', 'hundetür', 'aufgeregte', 'gewellt', 'feilten', 'albernes', 'sportstreifen', 'trium@@', 'stadtpark', 'schlauch', 'sichert', 'kreide@@', 'schwarzer', 'transparente', 'fischerboote', 'gehweg', 'wakeboarded', 'gestie@@', 'rollstühlen', '9', 'u', 'dj-spiel', 'us-@@', 'freitag', 'supermarkt', 'afrikanisches', 'erklärt', 'abfälle', 'mehreren', 'agility-@@', '-bh', 'turnt', 'zigarette', 'untersucht', 'videokamera', 'zauberteppich', 'verraten', 'oder', 'gehörschutz@@', 'spinn@@', 'mäher', 'akrobatischen', 'bins', 'ro', 'sei', 'gegenständen', 'geteerten', 'feuerrotem', 'alleine', 'herumspringenden', 'tarnhose', 'bergstraße', 'drängt', 'eishockeyspieler', 'uteter', 'igungstrupp', 'jet', 'konzentriert', 'imbiss@@', 'ziehen', 'dojo', 'verkleidet', 'walk', 'straßentrom@@', 'herabhängen', 'bunte', 'turnerinnen', 'digital', 'sumpfgebiet', 'visier', 'ignoriert', 'baseballteam', 'gefangenen', 'verfär@@', 'kimono', 'waage', 'leckeren', 'schließen', 'abgebro@@', 'west@@', 'stutzt', 'jahrmarktspielen', 'sommer@@', 'majestä@@', 'gebeugtem', 'kai', 'damenunterwäsche', 'seltsamer', 'senf', 'fußball-@@', 'grimasse', 'absolut', 'for@@', 'künstlichen', 'erstaun@@', 'chtsprung', 'marine', 'apple-@@', 'fußballschiedsrichter', 'beworfen', 'wandbild', 'turm', 'butterbrot', 'orientalisch', 'dachterrasse', 'rosaroter', 'blumen@@', 'violine', 'gremium', 'internationalem', 'aufgelegt', 'ener@@', 'flugzeug', 'schlecht', 'braungebran@@', 'gruppenbild', 'stillen', 'bedienungspult', 'diskussi@@', 'gymnastik-@@', 'gesichertes', 'schwimmring', 'vorderen', 'unsichtbaren', 'polizeiauto', 'glücklich', 'um', 'trainiert', 'zurück', 'allen', 'wäschebehälter', 'schwebt', 'dunkel@@', 'setzt', 'izabella', 'gereinigt', 'pi@@', 'schachtel', 'chinesisch', 'skate-park', 'wohl', 'golischen', 'spruch@@', 'stofftiere', 'lenkrad', 'befördern', 'rockstar', 'felsens', 'kleidung', 'ohrstöpseln', 'balance', 'musikstand', ...

# %%
# apply dictionary to target data
target_data_indexed = target_dictionary.apply_mapping(target_data_encoded)

# %%
# apply dictionary to source data
source_data_indexed = source_dictionary.apply_mapping(source_data_encoded)

# %% [markdown]
# # Batching

# %%
# initialize batcher
batcher = Batcher(source_data_indexed, target_data_indexed, BATCH_SIZE, WINDOW_SIZE)

# %%
# create batches
batcher.batch()

# %%
batches = batcher.getBatches()
